# %%
import pandas as pd

# %%
df=pd.read_parquet('output/polars_result.parquet')
df.head(10)
# Out:
#     SMA_5  SMA_10  SMA_20  SMA_30  SMA_50  SMA_60  SMA_100  SMA_120  SMA_200  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 4  11.612     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 5  11.670     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 6  11.702     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 7  11.720     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 8  11.682     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 9  11.614  11.613     NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#    SMA_250  ...  MACD_Cross  RSI_Overbought_70  RSI_Oversold_30  \
# ...
